# %%
import json
import pandas as pd
import requests
import twitter

# %%
import matplotlib.pyplot as plt
import wordcloud

# %%
import itertools

# %%
# reading the data from the file 
with open('twitter_dict.txt') as f: 
    data = f.read() 
    authentification = json.loads(data)

# %%
api = twitter.Api(consumer_key=authentification['API_key'],
                  consumer_secret=authentification['API_secret_key'],
                  access_token_key=authentification['Access_token'],
                  access_token_secret=authentification['Access_token_secret'],
                 tweet_mode='extended')

# %%
banks = {"Česká spořitelna":"ceskasporitelna",
         "Československá obchodní banka":"csob_cz",
         "Komerční Banka":"komercka",
         "UniCredit":"unicredit_czsk",
         "Raiffeisenbank":"raiffeisencz"}

# %%
banks
# Out:
# {'Česká spořitelna': 'ceskasporitelna',
#  'Československá obchodní banka': 'csob_cz',
#  'Komerční Banka': 'komercka',
#  'UniCredit': 'unicredit_czsk',
#  'Raiffeisenbank': 'raiffeisencz'}

# %%
class Comparison_collection():
    '''
    Class containing methods for comparing among different twitter users posts and their mentions posts. 
    '''
    
    def __init__(self,dictionary, authentification):
        '''
        Loads a dictionary with {"full_name":"twitter_handle"} pairs and saves this logic
        also creates an python-twitter API object based on a dictionary with API keys,
        consumer key and secret must be called API_key and API_secret_key respectively,
        access token key and access token secret must be called Access_token and Access_token_secret respectively
        '''

        self.users = dictionary
        
    
        self.api = twitter.Api(consumer_key=authentification['API_key'],
                  consumer_secret=authentification['API_secret_key'],
                  access_token_key=authentification['Access_token'],
                  access_token_secret=authentification['Access_token_secret'],
                 tweet_mode='extended')
    
    def create_user_data(self):
        
        for name in self.users:
            
            self.accounts = {name: Twitter_user(self.users[name], self.api) for name in self.users}
            
    def get_users_tweets(self):
        
        for name in self.users:
            
            self.accounts[name].gather_tweets()

# %%
class Twitter_user():
    '''
    Class containing timeline (list of all recent tweets), mentions statistics about their posts
    
    '''
    
    def __init__(self, twitter_handle, api, n_tweets_history = None):

        if n_tweets_history is None:
            n_tweets_history = 300
            
        self.reply_pd =[]
        self.n_tweets_history = n_tweets_history
        self.twitter_handle = twitter_handle
        self.api = twitter.Api(consumer_key=authentification['API_key'],
                  consumer_secret=authentification['API_secret_key'],
                  access_token_key=authentification['Access_token'],
                  access_token_secret=authentification['Access_token_secret'],
                 tweet_mode='extended')
        
    def get_timeline(self):
        self.timeline = self.api.GetUserTimeline(screen_name=self.twitter_handle, count = self.n_tweets_history)
        
    def get_mentions(self):
        self.mentions = self.api.GetSearch(term=self.twitter_handle,include_entities=True, count = self.n_tweets_history, result_type='recent')
        
    def gather_tweets(self):
        self.get_mentions()
        self.get_timeline()
        
    def get_account_details(self):
        '''
        requires at least one tweet in the timeline attribute Call get_timeline() or gather_tweets() to construct it
        '''
        self.details = {}
        self.detail_atributes_required = ('favourites_count', 'followers_count', 'friends_count', 'statuses_count')
        self.details = {k: self.timeline[1]._json['user'][k] for k in self.detail_atributes_required}
        print(self.details)
        
        
        
        
    def extract_mention_user_data(self):
        
        self.interesting_atributes = ['screen_name', 'favourites_count', 'followers_count', 'friends_count', 'statuses_count', 'location']
        for num, tweet in enumerate(rajf.mentions, start=0):
            self.mentions[num].user_info = (
                {k: self.mentions[num]._json['user'][k] for k in self.interesting_atributes}
            )
            self.mentions[num].user_info_pd = pd.DataFrame( self.mentions[num].user_info,
                                                           index =  [self.mentions[num].user_info['screen_name']])
        
    def extract_mention_tweet_data(self):    
        
        tweet_attributes = ['full_text', 'lang', 'retweet_count', 'source']
            
        for num, tweet in enumerate(self.mentions, start=0):
            self.mentions[num].tweet_info = (
                {k: self.mentions[num]._json[k] for k in tweet_attributes}
            )
            
        
    def generate_mentions_pdf(self):
        for num, tweet in enumerate(rajf.mentions, start=0):
            self.mentions[num].tweet_pd = pd.DataFrame( {**self.mentions[num].user_info, **self.mentions[num].tweet_info},
                                                           index =  [self.mentions[num].user_info['screen_name']])
            
        
        
    def extract_timeline_tweet_data(self):    
        
        tweet_attributes = ['full_text', 'lang', 'retweet_count', 'source']
            
        for num, tweet in enumerate(self.timeline, start=0):
            self.timeline[num].tweet_info = (
                {k: self.timeline[num]._json[k] for k in tweet_attributes}
            )
            
    def generate_timeline_pdf(self):
        for num, tweet in enumerate(self.mentions, start=0):
            self.timeline[num].tweet_pd = pd.DataFrame( {**self.timeline[num].tweet_info, **self.details},
                                                           index =  [self.timeline[num].user.screen_name])
        self.my_pd_list = [rajf.mentions[n].tweet_pd for n in list(range(0, len(rajf.mentions)))]
        self.my_pd = pd.concat(self.my_pd_list)
        
    def get_replied_to_tweet(self):
        for num, tweet in enumerate(self.timeline, start=0):
            if self.timeline[num].in_reply_to_status_id is None:
                self.timeline[num].reply_tweet = None
            else:
                try:
                    self.timeline[num].reply_tweet = api.GetStatus(self.timeline[num].in_reply_to_status_id)
                except twitter.TwitterError: 
                    self.timeline[num].reply_tweet = None
                else:
                    pass
                    
    def get_replied_to_user(self):
        for num, tweet in enumerate(self.timeline, start=0):
            if self.timeline[num].in_reply_to_user_id is None:
                self.timeline[num].reply_user = None
            else:
                try:
                    self.timeline[num].reply_user = api.GetUser(self.timeline[num].in_reply_to_user_id)
                except: 
                    self.timeline[num].reply_user = None
                else:
                    pass
                
                
    def extract_replied_to_tweet_info(self):
        self.reply_atributes_required = ('created_at', 'full_text', 'retweet_count', 'favorite_count')
        self.reply_user_required = ('screen_name', 'followers_count', 'friends_count', 'statuses_count', "favourites_count")
        for num, tweet in enumerate(self.timeline, start=0):

            if self.timeline[num].reply_tweet is None:
                if self.timeline[num].reply_user is None:
                    self.timeline[num].reply_info = (
                    {k: None for k in self.reply_atributes_required + self.reply_user_required}
                )
                else:
                    user_info = {k: getattr(self.timeline[num].reply_user, k) for k in self.reply_user_required}
                    tweet_info = {k: None for k in self.reply_atributes_required}

                    self.timeline[num].reply_info = {**user_info, **tweet_info}
            else:
                user_info = {k: getattr(self.timeline[num].reply_user, k) for k in self.reply_user_required}
                tweet_info = {k: getattr(self.timeline[num].reply_tweet, k) for k in self.reply_atributes_required}
                self.timeline[num].reply_info = {**user_info, **tweet_info}
                
                
    def generate_reply_pdf(self):
        for num, tweet in enumerate(self.timeline, start=0):
            self.reply_pd.append(pd.DataFrame(self.timeline[num].reply_info,
                                                       index =  [self.timeline[num].user.screen_name])
                                )
    def generate_reply_pdf_2(self):
        self.my_reply_pd_list = [self.reply_pd[num] for num in list(range(0, len(rajf.timeline)))]
        self.my_reply_pd = pd.concat(self.my_reply_pd_list)

# %%
rajf

# %%
rajf = Twitter_user('raiffeisencz', authentification, n_tweets_history = 300)
rajf.gather_tweets()
rajf.extract_mention_tweet_data()
rajf.extract_timeline_tweet_data()
rajf.get_replied_to_tweet()

# %%
rajf.get_replied_to_user()

# %%
rajf.extract_replied_to_tweet_info()

# %%
rajf.generate_reply_pdf()

# %%
rajf.timeline[2].reply_pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-120-5660c9dcbb73> in <module>
# ----> 1 rajf.timeline[2].reply_pd
#
# AttributeError: 'Status' object has no attribute 'reply_pd'

# %%
rajf.generate_reply_pdf_2()

# %%
rajf.my_reply_pd
# Out:
#                   screen_name followers_count friends_count statuses_count  \
# RaiffeisenCZ        josefhrib              15            81            205
# RaiffeisenCZ           OK1XPM             132           346          35821
# RaiffeisenCZ        josefhrib              15            81            205
# RaiffeisenCZ      jansladek38              17            49           3312
# RaiffeisenCZ           mcumpl             262           698           4992
# ...                       ...             ...           ...            ...
# RaiffeisenCZ  mnstrwtheyeptch               7           155            132
# RaiffeisenCZ             None            None          None           None
# RaiffeisenCZ             None            None          None           None
# RaiffeisenCZ             None            None          None           None
# RaiffeisenCZ             None            None          None           None
#
#              favourites_count                      created_at  \
# ...

# %%
rajf.timeline[num].reply_info_info
# Out:
# {'screen_name': 'PavelJan4',
#  'followers_count': 5,
#  'friends_count': 217,
#  'statuses_count': 2347,
#  'favourites_count': 43,
#  'created_at': 'Mon Jan 04 16:08:33 +0000 2021',
#  'full_text': '@RaiffeisenCZ Dobrý den, kde najdu seznam vkladomatů a jakou částkou jsou vklady do vkladomatů limitovány? Stejně tak bych se rád zeptal, zda a jak jsou limitovány výběry z vašich bankomatů?',
#  'retweet_count': 0,
#  'favorite_count': 0}

# %%
rajf.reply_info_info

# %%
dir(rajf.timeline[105].reply_user) ## status object no reply
# Out:
# ['AsDict',
#  'AsJsonString',
#  'NewFromJsonDict',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_json',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'email',
#  'favourites_count',
#  'followers_count',
#  'following',
#  'friends_count',
#  'geo_enabled',
#  'id',
#  'id_str',
#  'lang',
#  'listed_count',
#  'location',
#  'name',
#  'notifications',
#  'param_defaults',
#  'profile_background_color',
#  'profile_background_image_url',
#  'profile_background_image_url_https',
#  'profile_background_tile',
#  'profile_banner_url',
# ...

# %%
rajf.timeline[105].reply_tweet.user_mentions[0].screen_name
# Out:
# 'RaiffeisenCZ'

# %%
dir(rajf.timeline[105].reply_tweet.user_mentions)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
product_list = ["hypotéka", "karta", "úvěr", "půjčka", "spoření", "george", "smartbanking", "investování", "poradce", "účty", "platby", "transakce", "vkladomat", "bankomat"]

# %%
cz_banks = Comparison_collection(banks, authentification)

# %%
cz_banks.create_user_data()

# %%
cz_banks.get_users_tweets()

# %%
contributors
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-b3bf088f852c> in <module>
# ----> 1 contributors
#
# NameError: name 'contributors' is not defined

# %%
cz_banks.accounts['Česká spořitelna'].timeline[1].contributors

# %%
cz_banks.accounts['Česká spořitelna'].timeline[1].followers_count
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-fb86d82be1e9> in <module>
# ----> 1 cz_banks.accounts['Česká spořitelna'].timeline[1].followers_count
#
# AttributeError: 'Status' object has no attribute 'followers_count'

# %%
dir(cz_banks.accounts['Česká spořitelna'].timeline[1])

# %%
dir(cz_banks.accounts['Česká spořitelna'].timeline[1]._json)

# %%
cz_banks.accounts['Česká spořitelna'].timeline[1]._json['user']

# %%
cz_banks.accounts['Česká spořitelna'].timeline[1]._json['user']['friends_count']
# Out:
# 1399

# %%
cz_banks.accounts['Česká spořitelna'].timeline[1]._json['user']['favourites_count']
cz_banks.accounts['Česká spořitelna'].timeline[1]._json['user']['followers_count']
cz_banks.accounts['Česká spořitelna'].timeline[1]._json['user']['friends_count']
# Out:
# 1399

# %%
cz_banks.accounts['Česká spořitelna'].timeline[1]._json['user']['followers_count']

# %%
 ['contributors',
 'coordinates',
 'created_at',
 'created_at_in_seconds',
 'current_user_retweet',
 'favorite_count',
 'favorited',
 'full_text',
 'geo',
 'hashtags',
 'id',
 'id_str',
 'in_reply_to_screen_name',
 'in_reply_to_status_id',
 'in_reply_to_user_id',
 'lang',
 'location',
 'media',
 'param_defaults',
 'place',
 'possibly_sensitive',
 'quoted_status',
 'quoted_status_id',
 'quoted_status_id_str',
 'retweet_count',
 'retweeted',
 'retweeted_status',
 'scopes',
 'source',
 'text',
 'truncated',
 'tweet_mode',
 'urls',
 'user',
 'user_mentions',
 'withheld_copyright',
 'withheld_in_countries',
 'withheld_scope'
 ]

# %%
dir(cz_banks.accounts['Česká spořitelna'].timeline[1])

# %%
dir(cz_banks.accounts['Česká spořitelna'])

# %%
cz_banks.individual_users['Česká spořitelna']

# %%
twitter.Api(consumer_key=authentification['API_key'],
                  consumer_secret=authentification['API_secret_key'],
                  access_token_key=authentification['Access_token'],
                  access_token_secret=authentification['Access_token_secret'],
                 tweet_mode='extended')

# %%
? twitter.TwitterError

# %%
 def get_replied_to_tweet(self):
        for num, tweet in enumerate(self.timeline, start=0):
            if self.timeline[num].in_reply_to_status_id is None:
                self.timeline[num].reply_tweet = None
            else:
                self.timeline[num].reply_tweet = api.GetStatus(self.timeline[num].in_reply_to_status_id)
                try:
                    self.timeline[num].reply_tweet = api.GetStatus(self.timeline[num].in_reply_to_status_id)
                except twitter.TwitterError: 
                    self.timeline[num].reply_tweet = None
                else:
                    self.timeline[num].reply_tweet = None
                    
    def get_replied_to_user(self):
        for num, tweet in enumerate(self.timeline, start=0):
            if self.timeline[num].in_reply_to_user_id is None:
                self.timeline[num].reply_user = None
            else:
                try:
                    self.timeline[num].reply_user = api.GetUser(self.timeline[num].in_reply_to_user_id)
                except: 
                    self.timeline[num].reply_user = None

# %%
rajf = Twitter_user('raiffeisencz', authentification)
rajf.gather_tweets()
rajf.extract_mention_tweet_data()
rajf.extract_timeline_tweet_data()
rajf.get_replied_to_tweet()

# %%
rajf.get_replied_to_tweet()

# %%
rajf.timeline[105].reply_tweet ## status object no reply
# Out:
# Status(ID=1346126379667116035, ScreenName=PavelJan4, Created=Mon Jan 04 16:08:33 +0000 2021, Text='@RaiffeisenCZ Dobrý den, kde najdu seznam vkladomatů a jakou částkou jsou vklady do vkladomatů limitovány? Stejně tak bych se rád zeptal, zda a jak jsou limitovány výběry z vašich bankomatů?')

# %%
rajf.timeline[105].reply_tweet.created_at
# Out:
# 'Mon Jan 04 16:08:33 +0000 2021'

# %%
rajf.timeline[105].created_at
# Out:
# 'Tue Jan 05 10:44:14 +0000 2021'

# %%
dir(rajf.timeline[105].reply_tweet)
# Out:
# ['AsDict',
#  'AsJsonString',
#  'NewFromJsonDict',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_json',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'created_at_in_seconds',
#  'current_user_retweet',
#  'favorite_count',
#  'favorited',
#  'full_text',
#  'geo',
#  'hashtags',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'lang',
#  'location',
#  'media',
#  'param_defaults',
#  'place',
#  'possibly_sensitive',
#  'quoted_status',
#  'quoted_status_id',
#  'quoted_status_id_str',
#  'retweet_count',
#  'retweeted',
# ...

# %%
from contextlib import suppress
# Out:
#   File "<ipython-input-120-217b6b762297>", line 3
#     with suppress(Exception):
#                              ^
# SyntaxError: unexpected EOF while parsing

# %%
rajf.get_replied_to_tweet()

# %%
rajf.timeline[5].in_reply_to_status_id
# Out:
# 1359537218717691906

# %%
rajf.gather_tweets()

# %%
rajf.extract_mention_user_data()

# %%
rajf.extract_mention_tweet_data()

# %%
rajf.extract_timeline_tweet_data()

# %%
rajf.timeline[1].in_reply_to_status_id
# Out:
# 1359858236799737857

# %%
rajf.timeline[1].
# Out:
#   File "<ipython-input-65-97bae1bd4da4>", line 1
#     rajf.timeline[1].
#                      ^
# SyntaxError: invalid syntax

# %%
dir(rajf.timeline[1])
# Out:
# ['AsDict',
#  'AsJsonString',
#  'NewFromJsonDict',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_json',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'created_at_in_seconds',
#  'current_user_retweet',
#  'favorite_count',
#  'favorited',
#  'full_text',
#  'geo',
#  'hashtags',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'lang',
#  'location',
#  'media',
#  'param_defaults',
#  'place',
#  'possibly_sensitive',
#  'quoted_status',
#  'quoted_status_id',
#  'quoted_status_id_str',
#  'retweet_count',
#  'retweeted',
# ...

# %%
rajf.generate_mentions_pdf()

# %%
rajf.get_account_details()
# Out:
# {'favourites_count': 245, 'followers_count': 2675, 'friends_count': 298, 'statuses_count': 3694}

# %%
rajf.details
# Out:
# {'favourites_count': 195,
#  'followers_count': 2616,
#  'friends_count': 301,
#  'statuses_count': 3593}

# %%
rajf.generate_timeline_pdf()

# %%
rajf.generate_pdf()

# %%
rajf.my_pd
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-a3488bc5a7bd> in <module>
# ----> 1 rajf.my_pd
#
# AttributeError: 'Twitter_user' object has no attribute 'my_pd'

# %%
import wordcloud

# %%
import stop_words

# %%
help(stop_words)
# Out:
# Help on package stop_words:
#
# NAME
#     stop_words
#
# PACKAGE CONTENTS
#     tests
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         StopWordError
#
#     class StopWordError(builtins.Exception)
#      |  Common base class for all non-exit exceptions.
#      |
#      |  Method resolution order:
#      |      StopWordError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.Exception:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
# ...

# %%
czech_stopwords = stop_words.get_stop_words('czech', cache=True)

# %%
type(czech_stopwords)
# Out:
# list

# %%
text = " ".join(fulltext for fulltext in rajf.my_pd.full_text)

stopwords = set(czech_stopwords)
stopwords.update(["s", "za", "se", "a", "to"])

# Generate a word cloud image
wordcloud_rajf = wordcloud.WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud_rajf, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
text = " ".join(review for review in df.description)

# %%
rajf.get_mentions()

# %%
rajf.mentions[1].__dict__
# Out:
# {'param_defaults': {'contributors': None,
#   'coordinates': None,
#   'created_at': None,
#   'current_user_retweet': None,
#   'favorite_count': None,
#   'favorited': None,
#   'full_text': None,
#   'geo': None,
#   'hashtags': None,
#   'id': None,
#   'id_str': None,
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_user_id': None,
#   'lang': None,
#   'location': None,
#   'media': None,
#   'place': None,
#   'possibly_sensitive': None,
#   'quoted_status': None,
#   'quoted_status_id': None,
#   'quoted_status_id_str': None,
#   'retweet_count': None,
#   'retweeted': None,
#   'retweeted_status': None,
#   'scopes': None,
#   'source': None,
#   'text': None,
#   'truncated': None,
#   'urls': None,
#   'user': None,
#   'user_mentions': None,
#   'withheld_copyright': None,
#   'withheld_in_countries': None,
#   'withheld_scope': None},
#  'contributors': None,
#  'coordinates': None,
# ...

# %%
api = twitter.Api(consumer_key=authentification['API_key'],
                  consumer_secret=authentification['API_secret_key'],
                  access_token_key=authentification['Access_token'],
                  access_token_secret=authentification['Access_token_secret'],
                 tweet_mode='extended')

# %%
api.VerifyCredentials()
# Out:
# User(ID=237874317, ScreenName=Roman_Ruzica)

# %%
banks
# Out:
# {'Česká spořitelna': 'ceskasporitelna',
#  'Československá obchodní banka': 'csob_cz',
#  'Komerční Banka': 'komercka',
#  'UniCredit': 'unicredit_czsk',
#  'Raiffeisenbank': 'raiffeisencz'}
